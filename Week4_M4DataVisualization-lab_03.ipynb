# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
#!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
    
import urllib.request

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite"
filename = "m4_survey_data.sqlite"

# Download the file
urllib.request.urlretrieve(url, filename)

print(f"File '{filename}' downloaded successfully.")
# Out:
# File 'm4_survey_data.sqlite' downloaded successfully.

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
#import sqlite3
#import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
#conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve 'ConvertedComp' data
QUERY = """
SELECT ConvertedComp
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a histogram
plt.figure(figsize=(10, 6))
plt.hist(df['ConvertedComp'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of ConvertedComp')
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve 'Age' data
QUERY = """
SELECT Age
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Set the plotting environment to display inline
# %matplotlib inline

# Plot a box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['Age'], vert=False)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve 'Age' and 'WorkWeekHrs' data
QUERY = """
SELECT Age, WorkWeekHrs
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['WorkWeekHrs'], alpha=0.5, color='blue')
plt.title('Scatter Plot of Age and WorkWeekHrs')
plt.xlabel('Age')
plt.ylabel('WorkWeekHrs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve 'WorkWeekHrs', 'CodeRevHrs', and 'Age' data
QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a bubble plot
plt.figure(figsize=(10, 6))
plt.scatter(df['WorkWeekHrs'], df['CodeRevHrs'], s=df['Age'], alpha=0.5, c='blue', edgecolors='black', linewidths=0.5)
plt.title('Bubble Plot of WorkWeekHrs and CodeRevHrs (Bubble Size: Age)')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve the top 5 databases respondents wish to learn next year
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) as Count
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY Count DESC
LIMIT 5
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['Count'], labels=df['DatabaseDesireNextYear'], autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Top 5 Databases Respondents Wish to Learn Next Year')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve median 'WorkWeekHrs' and 'CodeRevHrs' for the age group 30 to 35
QUERY = """
SELECT Age,
       AVG(WorkWeekHrs) as MedianWorkWeekHrs,
       AVG(CodeRevHrs) as MedianCodeRevHrs
FROM master
WHERE Age BETWEEN 30 AND 35
GROUP BY Age
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a stacked chart
plt.figure(figsize=(10, 6))
plt.bar(df['Age'], df['MedianWorkWeekHrs'], label='Median WorkWeekHrs', color='skyblue')
plt.bar(df['Age'], df['MedianCodeRevHrs'], bottom=df['MedianWorkWeekHrs'], label='Median CodeRevHrs', color='orange')
plt.xlabel('Age Group (30 to 35)')
plt.ylabel('Median Hours')
plt.title('Stacked Chart of Median WorkWeekHrs and CodeRevHrs for Age Group 30 to 35')
plt.legend()
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve average 'ConvertedComp' for ages from 45 to 60
QUERY = """
SELECT Age, AVG(ConvertedComp) as MedianConvertedComp
FROM master
WHERE Age BETWEEN 45 AND 60
GROUP BY Age
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot the average 'ConvertedComp'
plt.figure(figsize=(10, 6))
plt.plot(df['Age'], df['MedianConvertedComp'], marker='o', linestyle='-')
plt.title('Average ConvertedComp for Ages 45 to 60')
plt.xlabel('Age')
plt.ylabel('Average Converted Compensation')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve the count of each 'MainBranch' value
QUERY = """
SELECT MainBranch, COUNT(*) as Count
FROM master
GROUP BY MainBranch
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(df['MainBranch'], df['Count'], color='skyblue')
plt.title('Distribution of MainBranch')
plt.xlabel('Count')
plt.ylabel('MainBranch')
plt.show()

# %%
import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# Get the list of columns in the 'master' table
columns_query = "PRAGMA table_info(master);"
columns_df = pd.read_sql_query(columns_query, conn)

# Display the list of columns
print("Columns in the 'master' table:")
print(columns_df['name'].tolist())
# Out:
# Columns in the 'master' table:
# ['index', 'Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor', 'OrgSize', 'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'FizzBuzz', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat', 'OpSys', 'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn', 'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st', 'SOVisitFreq', 'SOFindAnswer', 'SOTimeSaved', 'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams', 'SOComm', 'WelcomeChange', 'Age', 'Trans', 'Dependents', 'SurveyLength', 'SurveyEase']

# %%
#In the list of most popular languages respondents wish to learn next year, what is the rank of Python?




import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# Get the list of columns in the 'master' table
columns_query = "PRAGMA table_info(LanguageDesireNextYear);"
columns_df = pd.read_sql_query(columns_query, conn)

# Display the list of columns
print("Columns in the 'LanguageDesireNextYear' table:")
print(columns_df['name'].tolist())
# Out:
# Columns in the 'LanguageDesireNextYear' table:
# ['Respondent', 'LanguageDesireNextYear']

# %%
#In the list of most popular languages respondents wish to learn next year, what is the rank of Python?

import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve the most popular languages respondents wish to learn next year
QUERY = """
SELECT LanguageDesireNextYear, COUNT(*) as Count
FROM LanguageDesireNextYear
WHERE LanguageDesireNextYear IS NOT NULL
GROUP BY LanguageDesireNextYear
ORDER BY Count DESC
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Find the rank of Python
python_rank = df[df['LanguageDesireNextYear'] == 'Python'].index[0] + 1

print(f"The rank of Python in the list of most popular languages respondents wish to learn next year is: {python_rank}")
# Out:
# The rank of Python in the list of most popular languages respondents wish to learn next year is: 3

# %%
#How many respondents indicated that they currently work with 'SQL'? 

#LanguageWorkedWith


import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# Get the list of columns in the 'master' table
columns_query = "PRAGMA table_info(LanguageWorkedWith);"
columns_df = pd.read_sql_query(columns_query, conn)

# Display the list of columns
print("Columns in the 'LanguageWorkedWith' table:")
print(columns_df['name'].tolist())
# Out:
# Columns in the 'LanguageWorkedWith' table:
# ['Respondent', 'LanguageWorkedWith']

# %%
#How many respondents indicated that they currently work with 'SQL'? 

#LanguageWorkedWith


import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# Get the list of columns in the 'master' table
columns_query = "PRAGMA table_info(DatabaseWorkedWith);"
columns_df = pd.read_sql_query(columns_query, conn)

# Display the list of columns
print("Columns in the 'DatabaseWorkedWith' table:")
print(columns_df['name'].tolist())
# Out:
# Columns in the 'DatabaseWorkedWith' table:
# ['Respondent', 'DatabaseWorkedWith']

# %%
#How many respondents indicated that they currently work with 'SQL'? 

import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to count respondents currently working with 'SQL'
sql_query = """
SELECT COUNT(*) as SQLRespondents
FROM LanguageWorkedWith
WHERE LanguageWorkedWith LIKE '%SQL%'
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Display the count of respondents working with 'SQL'
print(f"Number of respondents currently working with SQL: {df['SQLRespondents'].values[0]}")
# Out:
# Number of respondents currently working with SQL: 7106

# %%
#How many respondents indicated that they work on 'MySQL' only? 

import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to count respondents currently working with 'SQL'
sql_query = """
SELECT COUNT(*) as SQLRespondents
FROM DatabaseWorkedWith
WHERE DatabaseWorkedWith = 'MySQL'
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Display the count of respondents working with 'SQL'
print(f"Number of respondents currently working with MySQL: {df['SQLRespondents'].values[0]}")



# SQL query to count respondents working on 'MySQL' only
sql_query = """
SELECT COUNT(*) as MySQLRespondentsNew
FROM LanguageWorkedWith
WHERE LanguageWorkedWith = 'MySQL'
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Display the count of respondents working on 'MySQL' only
print(f"Number of respondents working on MySQL only: {df['MySQLRespondentsNew'].values[0]}")
# Out:
# Number of respondents currently working with MySQL: 5469
# Number of respondents working on MySQL only: 0

# %%
#Majority of the survey responders are

import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to find the majority response in the 'MainBranch' column
sql_query = """
SELECT MainBranch, COUNT(*) as RespondentCount
FROM master
GROUP BY MainBranch
ORDER BY RespondentCount DESC
LIMIT 1
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Display the majority response in the 'MainBranch' column
majority_main_branch = df['MainBranch'].values[0]
respondent_count = df['RespondentCount'].values[0]

print(f"Majority of survey responders are: {majority_main_branch} (Count: {respondent_count})")
# Out:
# Majority of survey responders are: I am a developer by profession (Count: 10618)

# %%
#Majority of the survey responders are

#DevType
import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# Get the list of columns in the 'master' table
columns_query = "PRAGMA table_info(DevType);"
columns_df = pd.read_sql_query(columns_query, conn)

# Display the list of columns
print("Columns in the 'DevType' table:")
print(columns_df['name'].tolist())
# Out:
# Columns in the 'DevType' table:
# ['Respondent', 'DevType']

# %%
#Majority of the survey responders are


import sqlite3
import pandas as pd

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to find the majority response in the 'MainBranch' column
sql_query = """
SELECT Respondent, COUNT(*) as RespondentCount, DevType
FROM DevType
GROUP BY DevType
ORDER BY RespondentCount DESC
LIMIT 1
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Display the majority response in the 'MainBranch' column
majority_main_branch = df['DevType'].values[0]
respondent_count = df['RespondentCount'].values[0]

#print(f"Majority of survey responders are: {majority_main_branch} (Count: {respondent_count})")
print(f"Majority of survey responders are: {majority_main_branch} (Count: {respondent_count})")
# Out:
# Majority of survey responders are: Developer, full-stack (Count: 6928)

# %%
#the Line Chart of Age and median ConvertedComp for the age group 25-30

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Open a database connection
conn = sqlite3.connect("m4_survey_data.sqlite")

# SQL query to retrieve the average 'ConvertedComp' for the age group 25-30
sql_query = """
SELECT Age, AVG(ConvertedComp) as MedianConvertedComp
FROM master
WHERE Age BETWEEN 25 AND 30
GROUP BY Age
"""

# Read the data into a DataFrame
df = pd.read_sql_query(sql_query, conn)

# Plot the line chart
plt.figure(figsize=(10, 6))
plt.plot(df['Age'], df['MedianConvertedComp'], marker='o', linestyle='-')
plt.title('Line Chart of Age and Average ConvertedComp (Age Group: 25-30)')
plt.xlabel('Age')
plt.ylabel('Average ConvertedComp')
plt.grid(True)
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
